# %% [markdown]
# 15/09/2023
#
# LAB07
#
# My Menu Driven Restaurant
#
# In the charming little town named "Culinary Haven", there stood a restaurant called "The Enchanted Fork". This restaurant was more than just a place to eat; it was a magical experience that left a lasting impression on all who visited. The restaurant is also famous for its management application that takes up customer orders.
#
# The software collects the order details for the customers. The application generates a unique orderid for each order based on the below specifications. The software system has a predefined menu of items and their prices, from which the user can select them.
#
# OrderID is created with the help of a combination of 5 random numbers generated with the help of a random library in Python. You can use random.randint() function to get one random integer at a time and the order id is generated by concatenating five such numbers.
#
# Apart from orderid, each order will have the items ordered and their quantity saved.
#
# The application has the following options in its menu:
#
# Create new order
#
# View Orders (List and calculate the bill for each order)
#
# Assumptions:
#
# Each order will have a unique orderID generated as per the specifications given.
#
# Each order can have multiple items.
#
# Once the order is completed, you may calculate the total order value
#
# You can set a predefined menu and price for the items
#
#
# Expectations:
#
# Identify the appropriate data storage mechanisms to store the order data effectively.
#
# Usage of functions
#
# menu items stored in the format: [["Rice",30],["Tea",10],.....]
#
# Each order needs to be saved in the following format
#
# {
#
# "Orderid": 56837,
#
# "items": [
#
# {
#
# "itemnumber": 2,
#
# "quantity": 1,
#
# },
#
# {
#
# "itemnumber": 1,
#
# "quantity": 1,
#
# },
#
# ]
#
# }
#
# Additional Task (Optional):
#
# Save the order details to the file
#
#
# Submission & Evaluation Rubrics:
#
# Lab 07.ipynb file in Moodle & GitHub
#
# Same rubrics for the previous labs

# %%
import random
def orders():
    order={
        "Orderid":orderid,
        "items":[
            {
                "itemnumber":itemnumber,
                "quantity":quantity
            }
        ]
    }

# %%
import random 

def menu():
    print("Menu Card\n")
    print("1. Chicken Biriyani \t:\t Rs.150\n")
    print("2. Fish curry and Rice \t:\t Rs.130\n")
    print("3. Egg Curry and Rice \t:\t Rs. 80\n")
    print("4. Chicken Pasta \t:\t Rs.140\n")
    print("Today's Special:\n")
    print("5. Continental Chicken Shawarma \t Rs.250")

id,oldid=[],[]
def Orderid():
    for i in range(5):
        if i==0:
            id.append(str(random.randint(1,9)))
        else:
            id.append(str(random.randint(0,9)))
    orderid="".join(id)
    unique(orderid)
    createOrder(orderid)
    viewOrder(orderid)


def unique(orderid):
    #to make sure the Order ID generated is unique we add each ID generated to a set to avoid repitition
    #and change the id if it has been already generated. 
    #if the Order ID generated is unique the program continues.
    if orderid in oldid:
        for i in range(5):
            if i==0:
                id.append(str(random.randint(1,9)))
            else:
                id.append(str(random.randint(0,9)))
        orderid="".join(id)
    else:
        oldid.append(orderid)

Orderid()

ITEM=[]
order={}
Menu=[]
def createOrder(orderid):
    menu()
    condition=input("Enter 'Y' if you want to place an order else enter 'N'.")
    while(condition=='Y'):
        itemnumber=input("Enter the serial number of the dish you would like to order: ")
        quantity=input("Enter the quantity of the above chosen dish you would like to order: ")
        item={
            "itemnumber":itemnumber,
            "quantity":quantity
        }
        ITEM.append(item)
        menuordered=[]
        if itemnumber=='1':
            menuordered.append("Chicken Biriyani")
            menuordered.append("150")
            menuordered.append(quantity)
        elif itemnumber=='2':
            menuordered.append("Fish curry and Rice")
            menuordered.append("130")
            menuordered.append(quantity)
        elif itemnumber=='3':
            menuordered.append("Egg Curry and Rice")
            menuordered.append("80")
            menuordered.append(quantity)
        elif itemnumber=='4':
            menuordered.append("Chicken Pasta")
            menuordered.append("140")
            menuordered.append(quantity)
        elif itemnumber=='5':
            menuordered.append("Continental Chicken Shawarma")
            menuordered.append("250")
            menuordered.append(quantity)
        else:
            print("Invalid input")
        Menu.append(menuordered)



        condition=input("Enter 'Y' if you want to choose another item else enter 'N'.")
    storeOrder(orderid)


def storeOrder(orderid):
    order={
        "Orderid":orderid,
        "items":ITEM
    }


def viewOrder(orderid):
    print("Your order details are as follows: ")
    print("-"*30)
    print("Order ID: ",orderid)
    print("-"*30)
    print("Name of the dish\t\tQuantity\tPrice")
    cost=0
    for i in Menu:
        for j in range(len(i)):
            print(j[0],"\t\t",j[1],"\t",int(j[1])*int(j[2]),"\n")
            cost=cost+int(j[1])*int(j[2])
    print("-"*30)
    print("Your total bill: ",cost)

    


                

viewOrder(order)



    




# while True:
#     print("Welcome to Culinary Haven's favourite restaurant 'The Enchanted Fork'. We hope you have a magical experience while you dine with us.")
#     print("The services we offer are listed below. On entering the serial number, based on your requirement, you will be directed accordingly.")
#     print("1. Create new order")
#     print("2. View Order")
#     print("3. Exit")

#     choice=input("Enter the serial number of your choice: ")

#     if choice=='1':
#         #createOrder()
#     elif choice=='2':
#         #viewOrder()
#     elif choice=='3':
#         print(You have chosen to exit. We hope you have a great day ahead!)
#         break
#     else:
#         print("Invalid Input. Please try again.")
#         break
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20476\3113561058.py in <module>
#      37         oldid.append(orderid)
#      38
# ---> 39 Orderid()
#      40
#      41 ITEM=[]
#
# ~\AppData\Local\Temp\ipykernel_20476\3113561058.py in Orderid()
#      19     orderid="".join(id)
#      20     unique(orderid)
# ---> 21     createOrder(orderid)
#      22     viewOrder(orderid)
#      23
#
# ~\AppData\Local\Temp\ipykernel_20476\3662523165.py in createOrder(orderid)
#      43 Menu=[]
#      44 def createOrder(orderid):
# ---> 45     menu()
#      46     condition=input("Enter 'Y' if you want to place an order else enter 'N'.")
#      47     while(condition=='Y'):
#
# UnboundLocalError: local variable 'menu' referenced before assignment

# %%
import random 

def menu():
    print("Menu Card\n")
    print("1. Chicken Biriyani \t\t:\t Rs.150\n")
    print("2. Fish curry and Rice \t\t:\t Rs.130\n")
    print("3. Egg Curry and Rice \t\t:\t Rs.80\n")
    print("4. Chicken Pasta \t\t:\t Rs.140\n")
    print("Today's Special:\n")
    print("5. Continental Chicken Shawarma :\t Rs.250")

id,oldid=[],[]
def Orderid():
    for i in range(5):
        if i==0:
            id.append(str(random.randint(1,9)))
        else:
            id.append(str(random.randint(0,9)))
    orderid="".join(id)
    unique(orderid)
    createOrder(orderid)
    viewOrder(orderid)


def unique(orderid):
    #to make sure the Order ID generated is unique we add each ID generated to a set to avoid repitition
    #and change the id if it has been already generated. 
    #if the Order ID generated is unique the program continues.
    if orderid in oldid:
        for i in range(5):
            if i==0:
                id.append(str(random.randint(1,9)))
            else:
                id.append(str(random.randint(0,9)))
        orderid="".join(id)
    else:
        oldid.append(orderid)

ITEM=[]
order={}
Menu=[]
def createOrder(orderid):
    menu()
    condition=input("Enter 'Y' if you want to place an order else enter 'N'.")
    while(condition=='Y'):
        itemnumber=input("Enter the serial number of the dish you would like to order: ")
        quantity=input("Enter the quantity of the above chosen dish you would like to order: ")
        item={
            "itemnumber":itemnumber,
            "quantity":quantity
        }
        ITEM.append(item)
        menuordered=[]
        if itemnumber=='1':
            menuordered.append("Chicken Biriyani")
            menuordered.append("150")
            menuordered.append(quantity)
        elif itemnumber=='2':
            menuordered.append("Fish curry and Rice")
            menuordered.append("130")
            menuordered.append(quantity)
        elif itemnumber=='3':
            menuordered.append("Egg Curry and Rice")
            menuordered.append("80")
            menuordered.append(quantity)
        elif itemnumber=='4':
            menuordered.append("Chicken Pasta")
            menuordered.append("140")
            menuordered.append(quantity)
        elif itemnumber=='5':
            menuordered.append("Continental Chicken Shawarma")
            menuordered.append("250")
            menuordered.append(quantity)
        else:
            print("Invalid input")
        Menu.append(menuordered)



        condition=input("Enter 'Y' if you want to choose another item else enter 'N'.")
    storeOrder(orderid)



def storeOrder(orderid):
    order={
        "Orderid":orderid,
        "items":ITEM
    }


def viewOrder(orderid):
    print("Your order details are as follows: ")
    print("-"*30)
    print("Order ID: ",orderid)
    print("-"*30)
    print("Name of the dish\t\tQuantity\tPrice")
    cost=0
    for i in Menu:
        for j in range(len(i)):
            print(j[0],"\t\t",j[1],"\t",int(j[1])*int(j[2]),"\n")
            cost=cost+int(j[1])*int(j[2])
    print("-"*30)
    print("Your total bill: ",cost)

    


Orderid()

viewOrder(order)



    




# while True:
#     print("Welcome to Culinary Haven's favourite restaurant 'The Enchanted Fork'. We hope you have a magical experience while you dine with us.")
#     print("The services we offer are listed below. On entering the serial number, based on your requirement, you will be directed accordingly.")
#     print("1. Create new order")
#     print("2. View Order")
#     print("3. Exit")

#     choice=input("Enter the serial number of your choice: ")

#     if choice=='1':
#         #createOrder()
#     elif choice=='2':
#         #viewOrder()
#     elif choice=='3':
#         print(You have chosen to exit. We hope you have a great day ahead!)
#         break
#     else:
#         print("Invalid Input. Please try again.")
#         break
# Out:
# Menu Card
#
# 1. Chicken Biriyani 		:	 Rs.150
#
# 2. Fish curry and Rice 		:	 Rs.130
#
# 3. Egg Curry and Rice 		:	 Rs. 80
#
# 4. Chicken Pasta 		:	 Rs.140
#
# Today's Special:
#
# 5. Continental Chicken Shawarma :	 Rs.250
# Your order details are as follows:
# ------------------------------
# Order ID:  73204
# ------------------------------
# Name of the dish		Quantity	Price
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20476\4239453668.py in <module>
#     107
#     108
# --> 109 Orderid()
#     110
#     111 viewOrder(order)
#
# ~\AppData\Local\Temp\ipykernel_20476\4239453668.py in Orderid()
#      20     unique(orderid)
#      21     createOrder(orderid)
# ---> 22     viewOrder(orderid)
#      23
#      24
#
# ~\AppData\Local\Temp\ipykernel_20476\4239453668.py in viewOrder(orderid)
#      99     for i in Menu:
# ...
